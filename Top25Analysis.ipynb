# %%
#Dependencies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint as pprint

# %%
#CSVS

final_top_25_QB = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\CleanedTop25QB.csv"
final_top_25_WR = "C:\\Users\\Owner\\Documents\\Data Science Bootcamp\\FinalProject\\FinalTop25WR.csv"

# %%
#Read CSVS

final_QB = pd.read_csv(final_top_25_QB)
final_WR = pd.read_csv(final_top_25_WR)

# %%
final_QB
# Out:
#     Unnamed: 0 Player_Id  Year_x  Rnd  Pick   Tm            Player Position  \
# 0            0  NewtCa00    2011  1.0     1  CAR        Cam Newton       QB
# 1            2  RyanMa00    2008  1.0     3  ATL         Matt Ryan       QB
# 2            3  WilsRu00    2012  3.0    75  SEA    Russell Wilson       QB
# 3            4  CulpDa00    1999  1.0    11  MIN  Daunte Culpepper       QB
# 4            5  BrooAa00    1999  4.0   131  GNB      Aaron Brooks       QB
# 5            6  DaltAn00    2011  2.0    35  CIN       Andy Dalton       QB
# 6            7  FlacJo00    2008  1.0    18  BAL        Joe Flacco       QB
# 7           10  McNaDo00    1999  1.0     2  PHI    Donovan McNabb       QB
# 8           13  VickMi00    2001  1.0     1  ATL      Michael Vick       QB
# 9           14  BulgMa00    2000  6.0   168  NOR       Marc Bulger       QB
# 10          16  CutlJa00    2006  1.0    11  DEN        Jay Cutler       QB
# ...

# %%
average_qb_AV_avg = final_QB['First4AV'].mean()
average_qb_AV_avg
# Out:
# 51.875

# %%
final_WR
# Out:
#     Unnamed: 0 Player_Id  Year_x  Rnd  Pick   Tm            Player Pos  \
# 0            0  MossRa00    1998    1    21  MIN        Randy Moss  WR
# 1            1  HoltTo00    1999    1     6  STL        Torry Holt  WR
# 2            4  JoneJu02    2011    1     6  ATL       Julio Jones  WR
# 3            5  JohnCh01    2001    2    36  CIN      Chad Johnson  WR
# 4            8  RisoAn00    1989    1    22  IND       Andre Rison  WR
# 5           12  JohnKe00    1996    1     1  NYJ  Keyshawn Johnson  WR
# 6           13  OwenTe00    1996    3    89  SFO     Terrell Owens  WR
# 7           15  WaynRe00    2001    1    30  IND      Reggie Wayne  WR
# 8           17  BrowAn04    2010    6   195  PIT     Antonio Brown  WR
# 9           18  JohnCa00    2007    1     2  DET    Calvin Johnson  WR
# 10          19  JennGr00    2006    2    52  GNB     Greg Jennings  WR
# 11          20  ColsMa00    2006    7   252  NOR   Marques Colston  WR
# ...

# %%
average_WR_AV_avg = final_WR['First4AV'].mean()
average_WR_AV_avg
# Out:
# 48.916666666666664
